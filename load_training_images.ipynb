# %%
pip install -r requirements.txt
# Out:
# Requirement already satisfied: absl-py==2.1.0 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from -r requirements.txt (line 1)) (2.1.0)
# Requirement already satisfied: astunparse==1.6.3 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from -r requirements.txt (line 2)) (1.6.3)
# Requirement already satisfied: bleach==6.1.0 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from -r requirements.txt (line 3)) (6.1.0)
# Requirement already satisfied: certifi==2024.7.4 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from -r requirements.txt (line 4)) (2024.7.4)
# Requirement already satisfied: charset-normalizer==3.3.2 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from -r requirements.txt (line 5)) (3.3.2)
# Requirement already satisfied: flatbuffers==24.3.25 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from -r requirements.txt (line 6)) (24.3.25)
# Requirement already satisfied: gast==0.6.0 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from -r requirements.txt (line 7)) (0.6.0)
# Requirement already satisfied: google-pasta==0.2.0 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from -r requirements.txt (line 8)) (0.2.0)
# Requirement already satisfied: grpcio==1.64.1 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from -r requirements.txt (line 9)) (1.64.1)
# Requirement already satisfied: h5py==3.11.0 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from -r requirements.txt (line 10)) (3.11.0)
# Requirement already satisfied: idna==3.7 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from -r requirements.txt (line 11)) (3.7)
# Requirement already satisfied: kaggle==1.6.14 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from -r requirements.txt (line 12)) (1.6.14)
# Requirement already satisfied: keras==3.4.1 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from -r requirements.txt (line 13)) (3.4.1)
# Requirement already satisfied: libclang==18.1.1 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from -r requirements.txt (line 14)) (18.1.1)
# Requirement already satisfied: Markdown==3.6 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from -r requirements.txt (line 15)) (3.6)
# Requirement already satisfied: markdown-it-py==3.0.0 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from -r requirements.txt (line 16)) (3.0.0)
# Requirement already satisfied: MarkupSafe==2.1.5 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from -r requirements.txt (line 17)) (2.1.5)
# Requirement already satisfied: mdurl==0.1.2 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from -r requirements.txt (line 18)) (0.1.2)
# Requirement already satisfied: ml-dtypes==0.3.2 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from -r requirements.txt (line 19)) (0.3.2)
# Requirement already satisfied: namex==0.0.8 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from -r requirements.txt (line 20)) (0.0.8)
# Requirement already satisfied: numpy==1.26.4 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from -r requirements.txt (line 21)) (1.26.4)
# Requirement already satisfied: opencv-python==4.10.0.84 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from -r requirements.txt (line 22)) (4.10.0.84)
# Requirement already satisfied: opt-einsum==3.3.0 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from -r requirements.txt (line 23)) (3.3.0)
# Requirement already satisfied: optree==0.12.1 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from -r requirements.txt (line 24)) (0.12.1)
# Requirement already satisfied: packaging==24.1 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from -r requirements.txt (line 25)) (24.1)
# Requirement already satisfied: pillow==10.4.0 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from -r requirements.txt (line 26)) (10.4.0)
# Requirement already satisfied: protobuf==4.25.3 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from -r requirements.txt (line 27)) (4.25.3)
# Requirement already satisfied: Pygments==2.18.0 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from -r requirements.txt (line 28)) (2.18.0)
# Requirement already satisfied: python-dateutil==2.9.0.post0 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from -r requirements.txt (line 29)) (2.9.0.post0)
# Requirement already satisfied: python-slugify==8.0.4 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from -r requirements.txt (line 30)) (8.0.4)
# Requirement already satisfied: requests==2.32.3 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from -r requirements.txt (line 31)) (2.32.3)
# Requirement already satisfied: rich==13.7.1 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from -r requirements.txt (line 32)) (13.7.1)
# Requirement already satisfied: setuptools==70.3.0 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from -r requirements.txt (line 33)) (70.3.0)
# Requirement already satisfied: six==1.16.0 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from -r requirements.txt (line 34)) (1.16.0)
# Requirement already satisfied: tensorboard==2.16.2 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from -r requirements.txt (line 35)) (2.16.2)
# Requirement already satisfied: tensorboard-data-server==0.7.2 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from -r requirements.txt (line 36)) (0.7.2)
# Requirement already satisfied: tensorflow==2.16.2 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from -r requirements.txt (line 37)) (2.16.2)
# Requirement already satisfied: termcolor==2.4.0 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from -r requirements.txt (line 38)) (2.4.0)
# Requirement already satisfied: text-unidecode==1.3 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from -r requirements.txt (line 39)) (1.3)
# Requirement already satisfied: tqdm==4.66.4 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from -r requirements.txt (line 40)) (4.66.4)
# Requirement already satisfied: typing_extensions==4.12.2 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from -r requirements.txt (line 41)) (4.12.2)
# Requirement already satisfied: urllib3==2.2.2 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from -r requirements.txt (line 42)) (2.2.2)
# Requirement already satisfied: webencodings==0.5.1 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from -r requirements.txt (line 43)) (0.5.1)
# Requirement already satisfied: Werkzeug==3.0.3 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from -r requirements.txt (line 44)) (3.0.3)
# Requirement already satisfied: wheel==0.43.0 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from -r requirements.txt (line 45)) (0.43.0)
# Requirement already satisfied: wrapt==1.16.0 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from -r requirements.txt (line 46)) (1.16.0)
#
# [notice] A new release of pip is available: 24.1.1 -> 24.1.2
# [notice] To update, run: pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
import cv2
import matplotlib.pyplot as plt
import os
import numpy

image_folder = r'/Users/christinadaniel/Desktop/ShipDetectionData/airbus-ship-detection/train_v2' 

image_names = os.listdir(image_folder)

image_path = image_folder + "/" + image_names[0]

# The color space of test_image is BGR
test_image = cv2.imread(image_path)

# Convert from BGR to RGB
test_image_RGB = cv2.cvtColor(test_image, cv2.COLOR_BGR2RGB)

# Normalize
test_image_RGB = test_image_RGB/255

plt.imshow(test_image_RGB)
plt.axis('off')
plt.show()
# Out:
# [[[0.41960784 0.41960784 0.46666667]
#   [0.46666667 0.4745098  0.52156863]
#   [0.58039216 0.59607843 0.63137255]
#   ...
#   [0.56470588 0.57254902 0.56862745]
#   [0.64705882 0.65098039 0.67058824]
#   [0.64313725 0.64313725 0.6745098 ]]
#
#  [[0.38431373 0.38431373 0.43137255]
#   [0.42745098 0.43529412 0.48235294]
#   [0.52941176 0.54509804 0.58039216]
#   ...
#   [0.55686275 0.56078431 0.56862745]
#   [0.63921569 0.64313725 0.6627451 ]
#   [0.64705882 0.64705882 0.67843137]]
#
#  [[0.34509804 0.35294118 0.4       ]
#   [0.39215686 0.4        0.44705882]
#   [0.47843137 0.49411765 0.52941176]
#   ...
#   [0.55294118 0.56862745 0.58039216]
#   [0.61568627 0.62745098 0.65490196]
#   [0.62352941 0.63529412 0.67058824]]
#
#  ...
#
#  [[0.21176471 0.25882353 0.21176471]
#   [0.2745098  0.32156863 0.28235294]
#   [0.40784314 0.45098039 0.42745098]
#   ...
#   [0.21176471 0.25490196 0.23921569]
#   [0.23529412 0.27058824 0.26666667]
#   [0.24705882 0.27058824 0.27058824]]
#
#  [[0.16470588 0.21176471 0.15686275]
#   [0.21568627 0.2627451  0.21568627]
#   [0.34117647 0.38039216 0.34901961]
#   ...
#   [0.21176471 0.25490196 0.23921569]
#   [0.22745098 0.2627451  0.25098039]
#   [0.22745098 0.2627451  0.25098039]]
#
#  [[0.22745098 0.27843137 0.21176471]
#   [0.25882353 0.30588235 0.25098039]
#   [0.35686275 0.39607843 0.36470588]
#   ...
#   [0.21568627 0.2627451  0.24705882]
#   [0.23137255 0.26666667 0.25490196]
#   [0.23137255 0.26666667 0.25490196]]]

# %%
from tensorflow.keras import layers, models

# %%
# Out:
# 0.5
